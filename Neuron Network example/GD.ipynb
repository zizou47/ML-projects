# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv('./data/clean_weather.csv', index_col= 0)
data = data.ffill()

# %%
data.head(15)
# Out:
#             tmax  tmin  rain  tmax_tomorrow
# 1970-01-01  60.0  35.0  0.00           52.0
# 1970-01-02  52.0  39.0  0.00           52.0
# 1970-01-03  52.0  35.0  0.00           53.0
# 1970-01-04  53.0  36.0  0.00           52.0
# 1970-01-05  52.0  35.0  0.00           50.0
# 1970-01-06  50.0  38.0  0.00           52.0
# 1970-01-07  52.0  43.0  0.00           56.0
# 1970-01-08  56.0  49.0  0.24           54.0
# 1970-01-09  54.0  50.0  0.40           57.0
# 1970-01-10  57.0  50.0  0.00           57.0
# 1970-01-11  57.0  50.0  0.31           58.0
# 1970-01-12  58.0  52.0  0.05           59.0
# 1970-01-13  59.0  54.0  0.25           58.0
# 1970-01-14  58.0  53.0  1.94           56.0
# 1970-01-15  56.0  51.0  0.63           61.0

# %%
data.plot.scatter('tmax', 'tmax_tomorrow')
plt.plot([30,120], [30,120], 'green')

# %% [markdown]
# $\hat{y} = w_{1} *  x_{1} + b$

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(data[['tmax']], data['tmax_tomorrow'])
# Out:
# LinearRegression()

# %%
data.plot.scatter("tmax", "tmax_tomorrow")
plt.plot(data["tmax"], lr.predict(data[["tmax"]]), "green")
plt.show()

# %%
print(f"weight: {lr.coef_[0]:.2f}")
print(f"bias: {lr.intercept_: .2f}")
# Out:
# weight: 0.82
# bias:  11.99

# %%
s =  lambda  a, b : (a +b)
t = s(5,4)
t
# Out:
# 9
